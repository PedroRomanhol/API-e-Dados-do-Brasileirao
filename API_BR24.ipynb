# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
info = requests.get('https://api.sofascore.com/api/v1/unique-tournament/325/season/58766/standings/total').json()

# %%
info
# Out:
# {'standings': [{'tournament': {'name': 'Brasileirão Série A',
#     'slug': 'brasileirao-serie-a',
#     'category': {'name': 'Brazil',
#      'slug': 'brazil',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'id': 13,
#      'flag': 'brazil',
#      'alpha2': 'BR'},
#     'uniqueTournament': {'name': 'Brasileirão Série A',
#      'slug': 'brasileirao-serie-a',
#      'primaryColorHex': '#C7FF00',
#      'secondaryColorHex': '#969696',
#      'category': {'name': 'Brazil',
#       'slug': 'brazil',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 13,
#       'flag': 'brazil',
#       'alpha2': 'BR'},
#      'userCount': 337266,
#      'hasPerformanceGraphFeature': True,
#      'id': 325,
#      'displayInverseHomeAwayTeams': False},
#     'priority': 442,
#     'isGroup': False,
#     'isLive': False,
#     'id': 83},
#    'type': 'total',
#    'name': 'Brasileiro Serie A',
#    'descriptions': [],
# ...

# %%
data = pd.json_normalize(info['standings'][0]['rows'])
data.head(5)
# Out:
#   descriptions  position  matches  wins  scoresFor  scoresAgainst       id  \
# 0           []         1        4     3         10              4  1036710
# 1           []         2        4     2          7              1  1036709
# 2           []         3        4     2          6              4  1036723
# 3           []         4        4     2          6              3  1036711
# 4           []         5        4     2          6              5  1036717
#
#    losses  draws  points  ... team.disabled team.national team.type team.id  \
# 0       1      0       9  ...         False         False         0    1958
# 1       0      2       8  ...         False         False         0    1977
# 2       0      2       8  ...         False         False         0    1999
# 3       1      1       7  ...         False         False         0    1967
# 4       1      1       7  ...         False         False         0    1955
#
# ...

# %%
response = requests.get('https://www.sofascore.com/tournament/football/brazil/brasileirao-serie-a/325#id:58766')
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Opera GX";v="109", "Not:A-Brand";v="8", "Chromium";v="123"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 OPR/109.0.0.0',
}

response = requests.get(
    'https://api.sofascore.com/api/v1/unique-tournament/325/season/58766/top-teams/overall',
    headers=headers,
)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'topTeams': {'avgRating': [{'team': {'name': 'Atlético Mineiro',
#      'slug': 'atletico-mineiro',
#      'shortName': 'Atlético Mineiro',
#      'userCount': 0,
#      'type': 0,
#      'id': 1977,
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Минейро'},
#       'shortNameTranslation': {}}},
#     'statistics': {'avgRating': 7.0634920634921,
#      'id': 18746,
#      'matches': 4,
#      'awardedMatches': 0}},
#    {'team': {'name': 'Athletico',
#      'slug': 'athletico',
#      'shortName': 'Athletico',
#      'userCount': 0,
#      'type': 0,
#      'id': 1967,
#      'teamColors': {'primary': '#52b030',
#       'secondary': '#52b030',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Паранаэнсе'},
#       'shortNameTranslation': {}}},
#     'statistics': {'avgRating': 7.0466666666667,
#      'id': 18741,
# ...

# %%
top_teams = response.json()

# %%
Cruzamentos_certos = pd.json_normalize(top_teams['topTeams']['accurateCrosses'])
Cruzamentos_certos = Cruzamentos_certos.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Passes_longos_certos = pd.json_normalize(top_teams['topTeams']['accurateLongBalls'])
Passes_longos_certos = Passes_longos_certos.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Passes_certos = pd.json_normalize(top_teams['topTeams']['accuratePasses'])
Passes_certos  = Passes_certos .drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Posse_de_bola_medio = pd.json_normalize(top_teams['topTeams']['averageBallPossession'])
Posse_de_bola_medio = Posse_de_bola_medio.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Rating_medio = pd.json_normalize(top_teams['topTeams']['avgRating'])
Rating_medio = Rating_medio.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Grandes_chances = pd.json_normalize(top_teams['topTeams']['bigChances'])
Grandes_chances = Grandes_chances.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Grandes_chances_perdidas = pd.json_normalize(top_teams['topTeams']['bigChancesMissed'])
Grandes_chances_perdidas = Grandes_chances_perdidas.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Jogos_sem_sofrer_gols = pd.json_normalize(top_teams['topTeams']['cleanSheets'])
Jogos_sem_sofrer_gols = Jogos_sem_sofrer_gols.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Bolas_afastadas = pd.json_normalize(top_teams['topTeams']['clearances'])
Bolas_afastadas = Bolas_afastadas.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Escanteios = pd.json_normalize(top_teams['topTeams']['corners'])
Escanteios = Escanteios.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Faltas = pd.json_normalize(top_teams['topTeams']['fouls'])
Faltas = Faltas.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Gols_sofridos = pd.json_normalize(top_teams['topTeams']['goalsConceded'])
Gols_sofridos = Gols_sofridos.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Gols_marcados = pd.json_normalize(top_teams['topTeams']['goalsScored'])
Gols_marcados = Gols_marcados.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Bola_na_trave = pd.json_normalize(top_teams['topTeams']['hitWoodwork'])
Bola_na_trave = Bola_na_trave.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Interceptacoes = pd.json_normalize(top_teams['topTeams']['interceptions'])
Interceptacoes = Interceptacoes.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Gols_de_penalti = pd.json_normalize(top_teams['topTeams']['penaltyGoals'])
Gols_de_penalti = Gols_de_penalti.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Penaltis_cometidos = pd.json_normalize(top_teams['topTeams']['penaltyGoalsConceded'])
Penaltis_cometidos = Penaltis_cometidos.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Cartao_vermelho = pd.json_normalize(top_teams['topTeams']['redCards'])
Cartao_vermelho = Cartao_vermelho.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Chutes = pd.json_normalize(top_teams['topTeams']['shots'])
Chutes = Chutes.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Chutes_no_gol = pd.json_normalize(top_teams['topTeams']['shotsOnTarget'])
Chutes_no_gol = Chutes_no_gol.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Dribles_certos = pd.json_normalize(top_teams['topTeams']['successfulDribbles'])
Dribles_certos = Dribles_certos.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Desarmes = pd.json_normalize(top_teams['topTeams']['tackles'])
Desarmes = Desarmes.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
Cartao_amarelo = pd.json_normalize(top_teams['topTeams']['yellowCards'])
Cartao_amarelo = Cartao_amarelo.drop(['team.slug',	'team.shortName',	'team.userCount',	'team.type', 'team.teamColors.primary',	'team.teamColors.secondary',	'team.teamColors.text',
                          'team.fieldTranslations.nameTranslation.ru', 'statistics.id', 'statistics.awardedMatches'], axis=1)

# %%
tp = pd.concat([Cartao_amarelo, Desarmes, Dribles_certos, Chutes_no_gol, Chutes, Cartao_vermelho, Penaltis_cometidos, Gols_de_penalti, Interceptacoes, Bola_na_trave, Gols_marcados, Gols_sofridos, Faltas, Escanteios,
               Bolas_afastadas, Jogos_sem_sofrer_gols, Grandes_chances_perdidas, Grandes_chances, Rating_medio, Posse_de_bola_medio, Passes_certos, Passes_longos_certos],
               sort=False)

# %%
nomes_dataframes = [
    , ,
    , , , ,
 , , , , ,
    Bolas_afastadas, , ,
    , ,,,
]
# Out:
#   File "<ipython-input-36-211dfa97726c>", line 2
#     , Desarmes,
#     ^
# SyntaxError: invalid syntax

# %%
ids = Cartao_amarelo.drop('statistics.yellowCards', axis=1)

# %%
## INSERINDO OS DADOS

ids['Cartao_vermelho'] = Cartao_vermelho['statistics.redCards']
ids['Cartao_amarelo'] = Cartao_amarelo['statistics.yellowCards']
ids['Faltas'] = Faltas['statistics.fouls']
ids['Penaltis_cometidos'] = Penaltis_cometidos['statistics.penaltiesCommited']
ids['Gols_de_penalti'] = Gols_de_penalti['statistics.penaltyGoals']
ids['Gols_marcados'] = Gols_marcados['statistics.goalsScored']
ids['Gols_sofridos'] = Gols_sofridos['statistics.goalsConceded']
ids['Jogos_sem_sofrer_gols'] = Jogos_sem_sofrer_gols['statistics.cleanSheets']
ids['Chutes'] = Chutes['statistics.shots']
ids['Chutes_no_gol'] = Chutes_no_gol['statistics.shotsOnTarget']
ids['Dribles_certos'] = Dribles_certos['statistics.successfulDribbles']
ids['Bola_na_trave'] =  Bola_na_trave['statistics.hitWoodwork']
ids['Escanteios'] =  Escanteios['statistics.corners']
ids['Posse_de_bola_medio'] =  Posse_de_bola_medio['statistics.averageBallPossession']
ids['Passes_certos'] =  Passes_certos['statistics.accuratePasses']
ids['Passes_longos_certos'] =  Passes_longos_certos['statistics.accurateLongBalls']
ids['Grandes_chances'] =  Grandes_chances['statistics.bigChances']
ids['Grandes_chances_perdidas'] =  Grandes_chances_perdidas['statistics.bigChancesMissed']
ids['Rating_medio'] =  Rating_medio['statistics.avgRating']
ids['Desarmes'] =  Desarmes['statistics.tackles']
ids['Interceptacoes'] =  Interceptacoes['statistics.interceptions']
ids['Bolas_afastadas'] =  Bolas_afastadas['statistics.clearances']

# %%
ids.head(1)
# Out:
#              team.name  team.id  statistics.matches  Cartao_vermelho  \
# 0  Atlético Goianiense     7314                   4                4
#
#    Cartao_amarelo  Faltas  Penaltis_cometidos  Gols_de_penalti  Gols_marcados  \
# 0              17      75                   2                1             10
#
#    Gols_sofridos  ...  Escanteios  Posse_de_bola_medio  Passes_certos  \
# 0              1  ...          23                 64.0           1994
#
#    Passes_longos_certos  Grandes_chances  Grandes_chances_perdidas  \
# 0                   118               10                         7
#
#    Rating_medio  Desarmes  Interceptacoes  Bolas_afastadas
# 0      7.063492        64              49              119
#
# [1 rows x 25 columns]
